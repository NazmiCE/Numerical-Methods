# %% [markdown]
# https://www.mdpi.com/2073-4360/12/12/2921
#
# The results and derivations of parameters are based on this research which describes the mathematical model of drug delivery for a swelling device.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

# Device 208035
L = 5.25
X_t = 8.5
m = 8.5/5.25
g = 1.49918 * 10**(-4)

t = np.linspace(0, 10*3600, 500)

# %%
b = np.array([1,2,3])
def logarithmic_expansion(f):
  global L
  global g
  global m

  return (L*np.exp(g*t)) / (1+(1/m)*(np.exp(g*t) - 1))

r = logarithmic_expansion(t)

t = t/3600

# %%
plt.plot(t, r)

# %%
# Device 307035
D = 1.30515 * 10 **(-3)
D1 = 7.37805 * 10 **(-4)
D2 = 2.22787 * 10 **(-3)
tc = 7200
L = 5.25
X_t = 8.5
m = 8.5/5.25
g = 1.17298 * 10**(-4)

t = np.linspace(0, 10*3600, 500)
r = logarithmic_expansion(t)
t = t/3600
plt.plot(t, r)

# %%
# Device 406035
D = 1.30515 * 10 **(-3)
D1 = 7.37805 * 10 **(-4)
D2 = 2.22787 * 10 **(-3)
tc = 7200
L = 5.25
X_t = 8
m = 8/5.25
g = 1.16996 * 10**(-4)

t = np.linspace(0, 10*3600, 500)
r = logarithmic_expansion(t)
t = t/3600
plt.plot(t, r)

# %% [markdown]
# Finding G parameters for Device 208035 by simplyfing the equation. Least square method is used to find g, but first a linearization should be made for simplicity.

# %% [markdown]
# ![WhatsApp Image 2022-11-28 at 13.12.41.jpeg](data:image/jpeg;base64,...)

# %%
x_t = np.array([5.25, 6.5, 7, 7.2, 7.5, 8, 8.1, 8.25, 8.49, 8.49, 8.49])
ln_fi = np.log((1/x_t) - (1/8.5))
print(ln_fi)
time_array = np.arange(0,11) * 3600
time_array
# Out:
# [-2.61963924 -3.31872116 -3.6805112  -3.85178293 -4.15496918 -4.91265489
#  -5.14822096 -5.63657372 -8.88412535 -8.88412535 -8.88412535]
# array([    0,  3600,  7200, 10800, 14400, 18000, 21600, 25200, 28800,
#        32400, 36000])

# %%
ln_constant = math.log((m-1)/(m*L))
ln_constant
# Out:
# -2.7260687066048885

# %%
df = pd.DataFrame([time_array,ln_fi]).T
df
# Out:
#           0         1
# 0       0.0 -2.619639
# 1    3600.0 -3.318721
# 2    7200.0 -3.680511
# 3   10800.0 -3.851783
# 4   14400.0 -4.154969
# 5   18000.0 -4.912655
# 6   21600.0 -5.148221
# 7   25200.0 -5.636574
# 8   28800.0 -8.884125
# 9   32400.0 -8.884125
# 10  36000.0 -8.884125

# %%
df[2] = df[0]*df[1]
df
# Out:
#           0         1              2
# 0       0.0 -2.619639      -0.000000
# 1    3600.0 -3.318721  -11947.396175
# 2    7200.0 -3.680511  -26499.680672
# 3   10800.0 -3.851783  -41599.255591
# 4   14400.0 -4.154969  -59831.556250
# 5   18000.0 -4.912655  -88427.787943
# 6   21600.0 -5.148221 -111201.572672
# 7   25200.0 -5.636574 -142041.657869
# 8   28800.0 -8.884125 -255862.810074
# 9   32400.0 -8.884125 -287845.661334
# 10  36000.0 -8.884125 -319828.512593

# %%
df[3] = df[0]**2
df
# Out:
#           0         1              2             3
# 0       0.0 -2.619639      -0.000000  0.000000e+00
# 1    3600.0 -3.318721  -11947.396175  1.296000e+07
# 2    7200.0 -3.680511  -26499.680672  5.184000e+07
# 3   10800.0 -3.851783  -41599.255591  1.166400e+08
# 4   14400.0 -4.154969  -59831.556250  2.073600e+08
# 5   18000.0 -4.912655  -88427.787943  3.240000e+08
# 6   21600.0 -5.148221 -111201.572672  4.665600e+08
# 7   25200.0 -5.636574 -142041.657869  6.350400e+08
# 8   28800.0 -8.884125 -255862.810074  8.294400e+08
# 9   32400.0 -8.884125 -287845.661334  1.049760e+09
# 10  36000.0 -8.884125 -319828.512593  1.296000e+09

# %%
sum_of_ti = np.sum(df[0])
print("ti", str(sum_of_ti))
sum_of_ti_sqr = np.sum(df[0]**2)
print("ti^2", str(sum_of_ti_sqr))
sum_of_ti_yi = np.sum(df[2])
print("tiyi",str(sum_of_ti_yi))

(sum_of_ti_yi - (ln_constant*sum_of_ti))/(sum_of_ti_sqr)
# Out:
# ti 198000.0
# ti^2 4989600000.0
# tiyi -1345085.8911739832
# -0.00016140057064017462

# %% [markdown]
# Since all data points are not provided and some close data points are read from graph the deviation from the actual value is normal.
